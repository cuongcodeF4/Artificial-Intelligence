# %% [markdown]
# <a href="https://colab.research.google.com/github/cuongcodeF4/Artificial-Intelligence/blob/main/Cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar100
(x_train,y_train),(x_test,y_test)= cifar100.load_data()
# Out:
# ...
# 169001437/169001437 [==============================] - 4s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
import matplotlib.pyplot as plt
hinh= x_train[5]   #Lấy hình ở vị trí thứ 5
plt.imshow(hinh,cmap=plt.cm.binary)
plt.show
print("So nay la:",y_train[5])
# Out:
# So nay la: [86]

# %%
for i in range(25):
  plt.subplot(5,7,i+1)  # 2 hàng 5 cột 
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title("So:{}".format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range(25,50):
  plt.subplot(7,8,i+1)  # 2 hàng 5 cột 
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title("So:{}".format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range(50,75):
  plt.subplot(8,10,i+1)  # 2 hàng 5 cột 
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title("So:{}".format(y_train[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense

model= Sequential()
model.add(Dense(512, input_shape = (32*32*3,), activation = 'relu'))
model.add(Dense(100,activation= 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 100)               51300
#
# ...
# Total params: 1,624,676
# Trainable params: 1,624,676
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((50000,32*32*3,))
x_train = x_train.astype('float32')/255
x_test = x_test.reshape((10000,32*32*3,))
x_test = x_test.astype('float32')/255

# %%
from keras.utils import to_categorical #Lệnh chuyển qua 

y_train = to_categorical(y_train, 100) #10 kênh 
y_test = to_categorical(y_test, 100)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs = 100, batch_size= 128) # Mỗi lần học chỉ 128 dữ liệu, không học hết 60000 dữ liệu , học tổng cộng 10 lần
test_loss, test_acc = model.evaluate(x_test,y_test)
print('test_accuracy:',test_acc)
print('test_loss:',test_loss)
model.save('model_cifar100.h5')
# Out:
# Epoch 1/100
# 391/391 [==============================] - 12s 31ms/step - loss: 1.5500 - accuracy: 0.6067
# Epoch 2/100
# 391/391 [==============================] - 12s 31ms/step - loss: 1.5236 - accuracy: 0.6107
# Epoch 3/100
# 391/391 [==============================] - 14s 36ms/step - loss: 1.5107 - accuracy: 0.6106
# Epoch 4/100
# 391/391 [==============================] - 12s 31ms/step - loss: 1.4988 - accuracy: 0.6127
# Epoch 5/100
# 391/391 [==============================] - 12s 31ms/step - loss: 1.5035 - accuracy: 0.6137
# Epoch 6/100
# 391/391 [==============================] - 12s 30ms/step - loss: 1.4983 - accuracy: 0.6150
# Epoch 7/100
# 391/391 [==============================] - 12s 30ms/step - loss: 1.4945 - accuracy: 0.6146
# Epoch 8/100
# 391/391 [==============================] - 11s 29ms/step - loss: 1.4918 - accuracy: 0.6154
# Epoch 9/100
# 391/391 [==============================] - 12s 29ms/step - loss: 1.4851 - accuracy: 0.6147
# Epoch 10/100
# ...
